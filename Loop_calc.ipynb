# %%
while True:
    print ("""
    1. Addition
    2. Substraction
    3. Multiplication
    4. Exit
    """)
    choice = input ("Enter your choice ")
    if choice == "1":
        num1 = float(input("Enter Number 1: "))
        num2 = float(input("Enter Number 2: "))
        print("Addition is: ", num1 + num2)
    elif choice == "2":
        num1 = float(input("Enter Number 1: "))
        num2 = float(input("Enter Number 2: "))
        print ("Substraction is: ", num1 - num2)
    elif choice == "3":
        num1 = float(input("Enter Number 1: "))
        num2 = float(input("Enter Number 2: "))
        print("Multipliaction is: ", num1 * num2)
    else:
        choice == "4"
        print("Exit")
        break
# Out:
#     1. Addition
#     2. Substraction
#     3. Multiplication
#     4. Exit
# Enter your choice  2
# Enter Number 1:  12
# Enter Number 2:  64
# Substraction is:  -52.0
#
#     1. Addition
#     2. Substraction
#     3. Multiplication
#     4. Exit
# Enter your choice  4
# Exit
